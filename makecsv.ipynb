# %%
import pandas as pd
import json
import re

# %%
table = pd.read_json('./static/data/lad_list_2021.json')

# Opening JSON file
with open('./static/data/lad_list_2021.json') as json_file:
    data = json.load(json_file)

# Opening JSON file
with open('./static/areareportsprgen.json') as json_file:
    reports = json.load(json_file)

# %%
table['Standfirst'] = 'Stand'
table['Population'] = 'Pop'
table['Age'] = 'Age'
table['Household'] = 'Household'
table['disability'] = 'disability'
table['religion'] = 'religion'
table['tenure'] = 'tenure'
table['marital'] = 'marital'
table['health'] = 'health'
table['hoursworked'] = 'hoursworked'
table['ethnicity'] = 'ethnicity'
table['economic'] = 'economic'
table['children'] = 'children'
table['care'] = 'care'


for i in table.index:
    sf = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("</p>")[0].split("<p>")[-1]
    sf = re.sub(r'<! -- .*--> ', "", sf)
    table['Standfirst'][i] = sf
    pop = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="population" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
    pop = re.sub(r'<! -- .*--> ', "", pop)
    table['Population'][i] = pop
    age = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="agemed" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
    age = re.sub(r'<! -- .*--> ', "", age)
    table['Age'][i] = age

    try:
        household = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="household" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        household = re.sub(r'<! -- .*--> ', "", household)
        table['Household'][i] = household
    except:
        table['Household'][i] = ""

    try:
        disability = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="disability" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        disability = re.sub(r'<! -- .*--> ', "", disability)
        table['disability'][i] = disability
    except:
        table['disability'][i] = ""

    try:
        religion = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="religion" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        religion = re.sub(r'<! -- .*--> ', "", religion)
        table['religion'][i] = religion
    except:
        table['religion'][i] = ""

    try:
        tenure = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="tenure" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        tenure = re.sub(r'<! -- .*--> ', "", tenure)
        table['tenure'][i] = tenure
    except:
        table['tenure'][i] = ""

    try:
        marital = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="marital" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        marital = re.sub(r'<! -- .*--> ', "", marital)
        table['marital'][i] = marital
    except:
        table['marital'][i] = ""

    try:
        health = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="health" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        health = re.sub(r'<! -- .*--> ', "", health)
        table['health'][i] = health
    except:
        table['health'][i] = ""

    try:
        hoursworked = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="hoursworked" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        hoursworked = re.sub(r'<! -- .*--> ', "", hoursworked)
        table['hoursworked'][i] = hoursworked
    except:
        table['hoursworked'][i] = ""

    try:
        ethnicity = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="ethnicity" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        ethnicity = re.sub(r'<! -- .*--> ', "", ethnicity)
        table['ethnicity'][i] = ethnicity
    except:
        table['ethnicity'][i] = ""

    try:
        economic = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="economic" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        economic = re.sub(r'<! -- .*--> ', "", economic)
        table['economic'][i] = economic
    except:
        table['economic'][i] = ""

    try:
        children = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="children" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        children = re.sub(r'<! -- .*--> ', "", children)
        table['children'][i] = children
    except:
        table['children'][i] = ""

    try:
        care = reports[table['code'][i]].split("<! -- Start of the article-->")[1].split("""<h2  id="care" >""")[1].split("""<div id="esc123"></div>""")[0].replace("<p>", "").replace("</h2>", "\n").replace("</p>", "\n").replace("<h4>", "").replace("</h4>", "\n").replace("<h5>", "").replace("</h5>", "").replace("\n\n", "\n")
        care = re.sub(r'<! -- .*--> ', "", care)
        table['care'][i] = care
    except:
        table['care'][i] = ""

print(table['care'][0])
# Out:
# Change in unpaid care provision
# The percentage of Adur residents that provided at least 50 hours of weekly unpaid care increased from 2.0% to 2.7% in the 10 years leading up to 2011.
# The percentage who reported providing between 20 and 49 hours of unpaid care each week remained close to 1.0%.
# The proportion of people providing 50 hours, or more, of weekly unpaid care increased at a similar rate to the figure for the whole of the South East (from 1.7% in 2001 to 2.0% in 2011). Across England, the percentage increased from 2.1% to 2.4%.
# The proportion of people providing 50 hours, or more, of weekly unpaid care in Adur remained close to 2.7%
# Percentage of usual residents in England, South East and Adur by care, March 2001 and March 2011

# %%
print(table['Household'][0])
# Out:
# More people cohabiting
# Adur saw the South East's third-largest rise in the proportion of households with an unmarried couple.
# In 2011, just over 1 in 10 (10%) households in Adur had an unmarried couple, compared with 8.3% in 2001. The percentage of households comprising just one person increased from 31% to 32%.
# Across the region, only Southampton (from 8.9% to 11%) and Dover (from 8.1% to 10%) saw a greater increase in the proportion of households with an unmarried couple.
# The percentage of households with a cohabiting couple was higher than across the South East
# Percentage of households that had an unmarried couple across local authority areas in the South East and the average across England, March 2011

# %%
table
# Out:
#           code          name  \
# 0    E07000223          Adur
# 1    E07000026     Allerdale
# 2    E07000032  Amber Valley
# 3    E07000224          Arun
# 4    E07000170      Ashfield
# ..         ...           ...
# 326  W06000006       Wrexham
# 327  E07000238      Wychavon
# 328  E07000128          Wyre
# 329  E07000239   Wyre Forest
# 330  E06000014          York
#
#                                             Standfirst  \
# 0    The religious profile of Adur changed substant...
# 1    Allerdale's population grew in the 10 years le...
# 2    Amber Valley's population grew in the 10 years...
# 3    Arun's population grew in the 10 years leading...
# 4    Ashfield's population grew in the 10 years lea...
# ..                                                 ...
# 326  Wrexham's population grew in the decade to 201...
# 327  Wychavon's population grew in the decade to 20...
# 328  Wyre's population grew older in the decade lea...
# 329  Wyre Forest's population grew older in the dec...
# 330  York's population expanded in the 10 years lea...
#
#                                             Population  \
# 0    The population passed 61,000\nIn the decade to...
# 1    The population passed 96,000\nBetween the last...
# 2    The population passed 120,000\nBetween the las...
# 3    The population reached nearly 150,000\nIn the ...
# 4    The population reached nearly 120,000\nIn the ...
# ..                                                 ...
# 326  The population passed 130,000\nIn the 10 years...
# 327  The population reached nearly 120,000\nIn the ...
# 328  The population reached nearly 110,000\nBetween...
# 329  The population reached nearly 98,000\nIn the 1...
# 330  The population reached nearly 200,000\nIn the ...
#
#                                                    Age  \
# 0    An older Adur\nCensus 2011 data also show a ch...
# 1    An older Allerdale\nCensus 2011 data also show...
# 2    An older Amber Valley\nCensus 2011 data also s...
# 3    An older Arun\nCensus 2011 data also show a ch...
# 4    An older Ashfield\nCensus 2011 data also show ...
# ..                                                 ...
# 326  An older Wrexham\nCensus 2011 data also show a...
# 327  An older Wychavon\nCensus 2011 data also show ...
# 328  An older Wyre\nCensus 2011 data also show a ch...
# 329  An older Wyre Forest\nCensus 2011 data also sh...
# 330  Average age stable in York\nLatest census data...
#
#                                              Household  \
# 0    More people cohabiting\nAdur saw the South Eas...
# 1    More people cohabiting\nThe percentage of hous...
# 2    Changing household dynamics\nThe percentage of...
# 3    Changing household dynamics\nThe percentage of...
# 4    More single parents\nAshfield saw the East Mid...
# ..                                                 ...
# 326  More single parents\n<! -- In the rare occasio...
# 327  Changing household dynamics\nThe percentage of...
# 328  More people cohabiting\nThe percentage of hous...
# 329  More people living alone\nWyre Forest saw the ...
# 330  Changing household dynamics\nThe percentage of...
#
#                                             disability  \
# 0    Rise in considerably limiting disability\nThe ...
# 1    Disability in Allerdale\nThe percentage of All...
# 2    Disability in Amber Valley\nThe percentage of ...
# 3    Disability in Arun\nThe percentage of Arun res...
# 4    Disability in Ashfield\nThe percentage of Ashf...
# ..                                                 ...
# 326  Disability in Wrexham\n<! -- In the rare occas...
# 327  Disability in Wychavon\nThe percentage of Wych...
# 328  Disability in Wyre\nWyre saw the North West's ...
# 329  Disability in Wyre Forest\nThe percentage of W...
# 330  Disability in York\nThe percentage of York res...
#
#                                               religion  \
# 0    Religion in Adur\nThe 2011 Census asked a volu...
# 1    Religion in Allerdale\nThe 2011 Census asked a...
# 2    Religion in Amber Valley\nThe 2011 Census aske...
# 3    Religion in Arun\nThe 2011 Census asked a volu...
# 4    Religion in Ashfield\nThe 2011 Census asked a ...
# ..                                                 ...
# 326  Religion in Wrexham\nThe 2011 Census asked a v...
# 327  Religion in Wychavon\nThe 2011 Census asked a ...
# 328  Religion in Wyre\nThe 2011 Census asked a volu...
# 329  Religion in Wyre Forest\nThe 2011 Census asked...
# 330  Religion in York\nThe 2011 Census asked a volu...
#
#                                                 tenure  \
# 0    Rise in private renting\nThe percentage of hou...
# 1    Rise in private renting\nPrivate renting incre...
# 2    Rise in private renting\nThe percentage of pri...
# 3    Rise in private renting\nThe percentage of hou...
# 4    Rise in private renting\nThe percentage of hou...
# ..                                                 ...
# 326  Rise in private renting\nThe percentage of pri...
# 327  Rise in private renting\nThe percentage of hou...
# 328  Rise in private renting\nThe percentage of hou...
# 329  Rise in private renting\nThe percentage of hou...
# 330  Rise in private renting\nThe percentage of pri...
#
#                                                marital  \
# 0    More single people in Adur\nThe percentage of ...
# 1    More single people in Allerdale\nThe percentag...
# 2    More adults are separated from partners\nThe p...
# 3    More adults are separated from partners\nThe p...
# 4    More single people in Ashfield\nThe percentage...
# ..                                                 ...
# 326  Fewer married people\nThe percentage of adults...
# 327  Changing relationships in Wychavon\nThe propor...
# 328  More single people in Wyre\nThe percentage of ...
# 329  More adults are separated from partners\nThe p...
# 330  More single people in York\nThe percentage of ...
#
#                                                 health  \
# 0    Health improved\nThe percentage of Adur reside...
# 1    Health improved\nThe percentage of Allerdale r...
# 2    Health improved\nThe percentage of Amber Valle...
# 3    Health improved\nThe percentage of Arun reside...
# 4    Health improved\nThe percentage of Ashfield re...
# ..                                                 ...
# 326  Health improved\nThe percentage of Wrexham res...
# 327  Health improved\nThe percentage of Wychavon re...
# 328  Health improved\nThe percentage of Wyre reside...
# 329  Health improved\nThe percentage of Wyre Forest...
# 330  Health improved\nThe percentage of York reside...
#
#                                            hoursworked  \
# 0    Fewer people worked long hours\nThe percentage...
# 1    Fewer people worked long hours\nThe percentage...
# 2    Fewer people worked long hours\nThe percentage...
# 3    Fewer people worked long hours\nThe percentage...
# 4    Fewer people worked long hours\nThe percentage...
# ..                                                 ...
# 326  Fewer people worked long hours\nThe percentage...
# 327  Fewer people worked long hours\nWychavon saw t...
# 328  More people worked short hours\nThe percentage...
# 329  Fewer people worked long hours\nThe percentage...
# 330  More people worked short hours\nThe percentage...
#
#                                              ethnicity  \
# 0    Ethnicity in Adur\nIn 2011, 96% of the local p...
# 1    Ethnicity in Allerdale\nIn 2011, 99% of the lo...
# 2    Ethnicity in Amber Valley\nIn 2011, 98% of the...
# 3    Ethnicity in Arun\nIn 2011, 97% of the local p...
# 4    Ethnicity in Ashfield\nIn 2011, 98% of the loc...
# ..                                                 ...
# 326
# 327  Ethnicity in Wychavon\nIn 2011, 98% of the loc...
# 328  Ethnicity in Wyre\nIn 2011, 98% of the local p...
# 329  Ethnicity in Wyre Forest\nIn 2011, 97% of the ...
# 330  Ethnicity in York\nIn 2011, 3.4% of the local ...
#
#                                               economic  \
# 0    Rise in rate of unemployment\nThe percentage o...
# 1    Changing work life\nThe percentage of Allerdal...
# 2    Rise in rate of self-employment\nThe percentag...
# 3    Rise in rate of unemployment\nThe percentage o...
# 4    Employment in Ashfield\nThe percentage of empl...
# ..                                                 ...
# 326  Rise in rate of employment\nThe percentage of ...
# 327  Changing work life\nThe percentage of Wychavon...
# 328  Changing work life\nThe percentage of Wyre res...
# 329  Rise in rate of unemployment\nThe percentage o...
# 330  More students\nYork saw Yorkshire and The Humb...
#
#                                               children  \
# 0    Changes in family structure\nThe percentage of...
# 1    More homes without children\nThe percentage of...
# 2    More homes without children\nThe percentage of...
# 3    Changes in family structure\nThe percentage of...
# 4    Changes in family structure\nThe percentage of...
# ..                                                 ...
# 326  Changes in family structure\n<! -- In the rare...
# 327  Changes in family structure\nThe percentage of...
# 328  Changes in family structure\nThe percentage of...
# 329  Fewer homes with adult children living with th...
# 330  Changes in family structure\nThe percentage of...
#
#                                                   care
# 0    Change in unpaid care provision\nThe percentag...
# 1    Change in unpaid care\nThe percentage of Aller...
# 2    Change in unpaid care\nThe percentage of Amber...
# 3    Change in unpaid care\nThe percentage of Arun ...
# 4    Change in unpaid care provision\nThe percentag...
# ..                                                 ...
# 326  Change in unpaid care\nThe percentage of Wrexh...
# 327  Change in unpaid care provision\nThe percentag...
# 328  Change in unpaid care\nThe percentage of Wyre ...
# 329  Change in unpaid care provision\nWyre Forest s...
# 330  Change in unpaid care\nThe percentage of York ...
#
# [331 rows x 16 columns]

# %%
table.to_csv('topicsspread.csv')

# %%
# Out:
# 'abc '
